# %% [markdown]
# # Tối ưu KNN với giảm chiều LDA

# %% [markdown]
# KNN : Duyệt k = [1,2,3,5,7,9,11,13,15], train/test split [(.8,.2), (.7,.3), (.6,.4)]
#
# - Dữ liệu đầy đủ, 9 classes  : 0.79382 seconds
# - Dữ liệu LDA, 9 classes     : 0.39405 seconds
# - Dữ liệu under sampling     : 0.12196 seconds
# - Dữ liệu under sampling LDA : 0.06223 seconds
#
# <span style="color: #90EE90;">-> Nhanh hơn ~50%<span>

# %% [markdown]
# ### Full data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, 
    classification_report, 
    confusion_matrix
)
import seaborn as sns
import numpy as np

SPLIT_RATIOS = [(0.8, 0.2), (0.7, 0.3), (0.6, 0.4)]

import os
BASE_DIR = os.path.dirname(
    os.path.dirname(
        os.path.dirname(
            os.path.abspath('notebook/preprocessing.ipynb'))))

df_4 = pd.read_csv(os.path.join(BASE_DIR, 'data/X_4_classes_LDA_2dims.csv'))
df_9 = pd.read_csv(os.path.join(BASE_DIR, 'data/X_9_classes_LDA_2dims.csv'))

X_4 = df_4.drop(columns=['Classification'])
y_4 = df_4['Classification']
X_9 = df_9.drop(columns=['Classification'])
y_9 = df_9['Classification']

def distance(array, value):
  array = np.array(array)
  value = np.array(value)
  return np.linalg.norm(array - value, ord = 1, axis=1)

def find_k_nearest_index(array, value, k):
  dists = distance(array, value)
  return np.argsort(dists)[:k]

def knn(X_features, y_class, split_ratios):
    acc_list =  []
    for k in [1,3,5,7,9,11,13,15]:
        avg_acc = 0
        for ratio in split_ratios:
            X_train, X_test, y_train, y_test = train_test_split(
                X_features, y_class, test_size=ratio[1], random_state=42, stratify=y_class
            )
            y_pred = np.zeros((len(y_test), 12))

            for i in range(len(X_test)):
                indexis = find_k_nearest_index(X_train, X_test.iloc[i], k=k)
                # print(f'{i}: ', end='')
                for idx in indexis:
                    # print(f'{idx} ', end='')
                    y_pred[i, y_train[idx]] += 1

            y_pred_class = np.zeros(len(y_test))
            for i in range(len(y_pred)):
                y_pred_class[i] = np.argmax(y_pred[i])

            y_test.reshape(len(y_test))

            knn_raw_acc = accuracy_score(y_test.reshape(len(y_test)), y_pred_class)
            avg_acc += knn_raw_acc
            print(f'Accuracy \033[31m{k}-NN\033[0m bằng dữ liệu gốc với train/test = \033[31m{ratio[0]}/{ratio[1]}\033[0m: \033[31m{knn_raw_acc}\033[0m')
        print(f'Avg accuracy với k = \033[31m{k}\033[0m: \033[31m{avg_acc / 3}\033[0m', end='\n')
        acc_list.append(avg_acc / 3)
            
    return acc_list

y_4_encoded = pd.factorize(y_4)[0]
y_9_encoded = pd.factorize(y_9)[0]
knn_acc_4 = knn(X_4, y_4_encoded, SPLIT_RATIOS)
import time
start_time = time.time()
knn_acc_9 = knn(X_9, y_9_encoded, SPLIT_RATIOS)
end_time = time.time()
# Out:
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.8925233644859814
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8909657320872274
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8852459016393442
# Avg accuracy với k = 1: 0.8895783327375177
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9065420560747663
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9096573208722741
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9110070257611241
# Avg accuracy với k = 3: 0.9090688009027215
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9299065420560748
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9221183800623053
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9320843091334895
# Avg accuracy với k = 5: 0.9280364104172899
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9252336448598131
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9127725856697819
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9250585480093677
# Avg accuracy với k = 7: 0.9210215928463209
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9205607476635514
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9127725856697819
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9203747072599532
# Avg accuracy với k = 9: 0.9179026801977622
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9252336448598131
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9096573208722741
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9180327868852459
# Avg accuracy với k = 11: 0.9176412508724444
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9205607476635514
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9127725856697819
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9250585480093677
# Avg accuracy với k = 13: 0.9194639604475671
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9158878504672897
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9127725856697819
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9227166276346604
# Avg accuracy với k = 15: 0.9171256879239107
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9049773755656109
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8851963746223565
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8775510204081632
# Avg accuracy với k = 1: 0.8892415901987102
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9230769230769231
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8942598187311178
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8866213151927438
# Avg accuracy với k = 3: 0.9013193523335948
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9276018099547512
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9063444108761329
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9024943310657596
# Avg accuracy với k = 5: 0.9121468506322147
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9366515837104072
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9214501510574018
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9160997732426304
# Avg accuracy với k = 7: 0.9247338360034799
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9230769230769231
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9154078549848943
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.909297052154195
# Avg accuracy với k = 9: 0.9159272767386707
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9366515837104072
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.9093655589123867
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9047619047619048
# Avg accuracy với k = 11: 0.9169263491282328
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9276018099547512
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.918429003021148
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.909297052154195
# Avg accuracy với k = 13: 0.9184426217100313
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9321266968325792
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.918429003021148
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.9115646258503401
# Avg accuracy với k = 15: 0.9207067752346892

# %%
print(f"KNN on original data took {round(end_time - start_time, 5)} seconds")
# Out:
# KNN on original data took 0.39405 seconds

# %%
plt.figure(figsize=(10, 6))
plt.plot([1,3,5,7,9,11,13,15], knn_acc_4, marker='o', label='4 Classes')
plt.plot([1,3,5,7,9,11,13,15], knn_acc_9, marker='o', label='9 Classes')
plt.title('K-NN Classifier Accuracy')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Avg Accuracy')
plt.xticks([1,3,5,7,9,11,13,15])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Đánh giá với k = 3 và k = 7

# %%
# Classification Report and Confusion Matrix for best k and best train/test split
best_k = 3
def knn_evaluate(X_features, y_class, k, test_size=0.2):
    X_train, X_test, y_train, y_test = train_test_split(
        X_features, y_class, test_size=test_size, random_state=42, stratify=y_class
    )
    y_pred = np.zeros((len(y_test), 12))

    for i in range(len(X_test)):
        indexis = find_k_nearest_index(X_train, X_test.iloc[i], k=k)
        for idx in indexis:
            y_pred[i, int(y_train[idx])] += 1

    y_pred_class = np.argmax(y_pred, axis=1).astype(int)

    print("Classification Report:")
    print(classification_report(y_test, y_pred_class, zero_division=0))

    cm = confusion_matrix(y_test, y_pred_class)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for {k}-NN')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

knn_evaluate(X_4, y_4_encoded, best_k)
knn_evaluate(X_9, y_9_encoded, best_k)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        50
#            1       0.96      0.96      0.96       140
#            2       0.17      0.14      0.15         7
#            3       0.67      0.71      0.69        17
#
#     accuracy                           0.91       214
#    macro avg       0.68      0.69      0.68       214
# weighted avg       0.90      0.91      0.91       214
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        50
#            1       0.96      0.94      0.95       140
#            2       0.57      0.57      0.57         7
#            3       0.89      0.94      0.92        18
#            4       0.00      0.00      0.00         2
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#            7       1.00      1.00      1.00         1
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.92       221
#    macro avg       0.59      0.60      0.60       221
# weighted avg       0.91      0.92      0.92       221

# %%
best_k = 7
knn_evaluate(X_4, y_4_encoded, best_k)
knn_evaluate(X_9, y_9_encoded, best_k)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        50
#            1       0.98      0.96      0.97       140
#            2       0.40      0.29      0.33         7
#            3       0.70      0.82      0.76        17
#
#     accuracy                           0.93       214
#    macro avg       0.75      0.76      0.75       214
# weighted avg       0.92      0.93      0.92       214
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        50
#            1       0.96      0.96      0.96       140
#            2       0.71      0.71      0.71         7
#            3       0.89      0.94      0.92        18
#            4       0.00      0.00      0.00         2
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#            7       1.00      1.00      1.00         1
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.94       221
#    macro avg       0.61      0.62      0.62       221
# weighted avg       0.92      0.94      0.93       221

# %% [markdown]
# ### Random under sampling for 4 classes

# %%
# under sampling for 4 classes for 36 samples each
df_4_under = df_4.copy()
df_4_under = df_4_under.groupby('Classification', group_keys=False).sample(n=36, random_state=42).reset_index(drop=True)
X_4_under = df_4_under.drop(columns=['Classification'])
y_4_under = df_4_under['Classification']
y_4_under_encoded = pd.factorize(y_4_under)[0]

import time
start_time = time.time()
acc_4_under = knn(X_4_under, y_4_under_encoded, SPLIT_RATIOS)
end_time = time.time()
# Out:
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.8275862068965517
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8636363636363636
# Accuracy 1-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.7931034482758621
# Avg accuracy với k = 1: 0.8281086729362591
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.896551724137931
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8636363636363636
# Accuracy 3-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8103448275862069
# Avg accuracy với k = 3: 0.8568443051201672
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9310344827586207
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8636363636363636
# Accuracy 5-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8103448275862069
# Avg accuracy với k = 5: 0.8683385579937304
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9310344827586207
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8636363636363636
# Accuracy 7-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8620689655172413
# Avg accuracy với k = 7: 0.8855799373040751
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9310344827586207
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8409090909090909
# Accuracy 9-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8793103448275862
# Avg accuracy với k = 9: 0.8837513061650992
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.896551724137931
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8181818181818182
# Accuracy 11-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8793103448275862
# Avg accuracy với k = 11: 0.8646812957157786
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.896551724137931
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8409090909090909
# Accuracy 13-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.7931034482758621
# Avg accuracy với k = 13: 0.843521421107628
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.8/0.2: 0.9310344827586207
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.7/0.3: 0.8181818181818182
# Accuracy 15-NN bằng dữ liệu gốc với train/test = 0.6/0.4: 0.8620689655172413
# Avg accuracy với k = 15: 0.8704284221525601
# Under sampling KNN took 0.062227725982666016 seconds

# %%
print(f"Under sampling KNN took {round(end_time - start_time, 5)} seconds")
# Out:
# Under sampling KNN took 0.06223 seconds

# %%
plt.figure(figsize=(10, 6))
plt.plot([1,3,5,7,9,11,13,15], acc_4_under, marker='o', label='4 Classes')
plt.title('K-NN Classifier Accuracy')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Avg Accuracy')
plt.xticks([1,3,5,7,9,11,13,15])
plt.legend()
plt.grid()
plt.show()

# %%
best_k_under = 7
knn_evaluate(X_4_under, y_4_under_encoded, best_k_under)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.88      1.00      0.93         7
#            2       0.89      1.00      0.94         8
#            3       1.00      0.86      0.92         7
#
#     accuracy                           0.93        29
#    macro avg       0.94      0.93      0.93        29
# weighted avg       0.94      0.93      0.93        29
